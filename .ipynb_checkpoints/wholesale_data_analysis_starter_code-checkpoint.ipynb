# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Resources/client_dataset.csv')
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# 0          17        2023  EUD29711-63-6U        decor            wall art
# 1          20        2023  XDA18116-89-4A  consumables                pens
# 2           4        2023  ABE59463-05-7E     software  project management
# 3          17        2023  ZMM00836-65-0C  consumables                pens
# 4          21        2023  BZX55559-12-3X  consumables                misc
#
#    unit_price  unit_cost  unit_weight  qty  line_number
# 0     1096.80     762.71         7.50  105            1
# 1       24.95      15.09         1.49   21            0
# 2       13.52       7.86         1.68   39            6
# 3       36.42      24.85         1.23   29            3
# 4      195.10     108.17        46.43   20            1

# %%
# View the column names in the data
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
df.describe()
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# min        0.010000      0.000000  0.000000e+00      0.000000
# 25%       14.840000      1.450000  3.200000e+01      1.000000
# 50%       49.890000      3.240000  6.800000e+01      3.000000
# 75%      125.570000      6.890000  1.700000e+02      5.000000
# max      846.270000     46.430000  3.958244e+06      9.000000

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
#df.head()
#df.iloc[1]
#df.iloc[4:9,2:8]
df.loc[5:8]
#df.count()
# Out:
#      first    last                                           job  \
# 5  Jessica   Reyes  Production designer, theatre/television/film
# 6    Brian   Moore                                       Barista
# 7    Jesus  Wright                            Theme park manager
# 8  Rebecca   Brown                                   Chiropodist
#
#                  phone                          email  client_id  order_id  \
# 5           5016915923       jessica.reyes@grimes.net      33615   1327730
# 6  +1-893-400-2733x982    moore.official@martinez.com      87213   8080280
# 7   605.947.9467x66513  wright.jesus.7579@meadows.com      46709   8946782
# 8     665-955-0156x926           rbrown850@lewis.info      73362   9394118
#
#    order_date  order_week  order_year         item_id     category  \
# 5  2023-05-02          18        2023  BMB23158-88-9A        decor
# 6  2023-04-19          16        2023  UAC50632-25-4E  consumables
# 7  2023-02-14           7        2023  UEU25316-01-1U  consumables
# 8  2023-05-13          19        2023  DDA06248-98-7Z  consumables
#
#         subcategory  unit_price  unit_cost  unit_weight  qty  line_number
# 5            plants      172.84     154.44         2.79   78            0
# 6  kitchen supplies      245.56     231.95         1.73   56            5
# 7              pens       20.99      16.97         5.12   22            4
# 8    paper products       83.86      59.00         0.27   49            3

# %%
# What three item categories had the most entries?
df_category = df["category"].value_counts()
df_category.head(3)
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries, which subcategory had the most entries?
#df = df.sort_index()
#df.head()
#df.set_index(df['category'],inplace=True )
#df.head()
#df_sort = df.sort_values("category", ascending=True)
#df_sort.head()
df_subcategory = df["subcategory"].loc[(df['category'] == "consumables")].value_counts()
df_subcategory.head(1)
# Out:
# subcategory
# bathroom supplies    6424
# Name: count, dtype: int64

# %%
# Which five clients had the most entries in the data?
df_clients = df['client_id'].value_counts()
#df_clients.head(5)
df_clients.sort_values
df_clients.head(5)
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.
clients_id = [33615, 66037, 46820, 38378, 24741]
clients_id
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How many total units (the qty column) did the client with the most entries order order?
df_units = df["qty"].loc[(df['client_id'] == 33615)].sum()
#df_units=df["qty"].value_counts()
df_units
# Out:
# 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the subtotal for each line using the unit_price and the qty
df_cleanup = df[['unit_price','qty']].copy()
df_cleanup.loc[:,'line_subtotal'] = df_cleanup['unit_price']*df_cleanup['qty']
df_cleanup.head(3)

#Alternate method : Create a column that calculates the subtotal for each line using the unit_price and the qty
#def sub_total(row):
#    return row['unit_price'] * row['qty']

#df_cleanup['sub_total'] = df_cleanup.apply(sub_total, axis = 1)
#df_cleanup.head()
# Out:
#    unit_price  qty  line_subtotal
# 0     1096.80  105      115164.00
# 1       24.95   21         523.95
# 2       13.52   39         527.28

# %%
df_shipping_price = df_cleanup[['unit_price','qty','line_subtotal']].copy()
df_shipping_price.head()
df_shipping_price['unit_weight'] = df[['unit_weight']].copy()
df_shipping_price['total_weight'] = df_shipping_price['unit_weight']*df_shipping_price['qty']
df_rearrange = df_shipping_price[['unit_price','unit_weight','qty','total_weight']]
df_rearrange.head(5)
# Out:
#    unit_price  unit_weight  qty  total_weight
# 0     1096.80         7.50  105        787.50
# 1       24.95         1.49   21         31.29
# 2       13.52         1.68   39         65.52
# 3       36.42         1.23   29         35.67
# 4      195.10        46.43   20        928.60

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound for orders over 50 pounds and $10 per pound for items 50 pounds or under.

def shipping_price(row):
    shipping_price = row['total_weight'] * 10
    if (row['total_weight'] > 50):
        shipping_price = row['total_weight'] * 7
        return shipping_price
    return shipping_price

df_rearrange['shipping_price'] = df_rearrange.apply(shipping_price, axis = 1)
df_rearrange.head(3)

#Alternate method using lambda/apply.

#df_rearrange.loc[:,'shipping_price'] = df_rearrange['unit_weight'].apply(lambda i: i*7 if i >50 else i*10)
#df_rearrange.head(3)
# Out:
#    unit_price  unit_weight  qty  total_weight  shipping_price
# 0     1096.80         7.50  105        787.50         5512.50
# 1       24.95         1.49   21         31.29          312.90
# 2       13.52         1.68   39         65.52          458.64

# %%
# Create a column for the total price using the subtotal and the shipping price along with a sales tax of 9.25%

#df_cleanup('line_price') = df_cleanup['subtotal'] + df_cleanup['shipping_price'] + df_cleanup['sales_tax']
df_rearrange['line_subtotal'] = df_rearrange['unit_price']*df_rearrange['qty']
#df_rearrange.head()

df_rearrange['sales_tax'] = round(df_rearrange['shipping_price'] + df_rearrange['line_subtotal']) * 0.0925
#df_rearrange.head()

def line_price(row):
    total_price = row['shipping_price'] + row['line_subtotal'] + row['sales_tax']
    #return f"{row['shipping_price'] + row['subtotal']}"
    return f"{total_price:.2f}"

df_rearrange['line_price'] = df_rearrange.apply(line_price, axis=1)
df_rearrange.head(3)
# Out:
#    unit_price  unit_weight  qty  total_weight  shipping_price  line_subtotal  \
# 0     1096.80         7.50  105        787.50         5512.50      115164.00
# 1       24.95         1.49   21         31.29          312.90         523.95
# 2       13.52         1.68   39         65.52          458.64         527.28
#
#     sales_tax line_price
# 0  11162.5300  131839.03
# 1     77.4225     914.27
# 2     91.2050    1077.12

# %%
# Create a column for the cost of each line using unit cost, qty, and
# shipping price (assume the shipping cost is exactly what is charged to the client).
df.loc[:,'line_cost'] = (df_rearrange.loc[:,'shipping_price']) + (df.loc[:,'unit_cost'] * df.loc[:,'qty']) 
df.head(3)
# Out:
#      first     last              job               phone  \
# 0   Donald  Harding     Immunologist  793-904-7725x39308
# 1  Tiffany    Myers  Music therapist    201.442.4543x942
# 2  Shannon   Watson     Immunologist   687.737.9424x8503
#
#                                email  client_id   order_id  order_date  \
# 0   harding.donald.7185@sullivan.com    58515.0  8953482.0  2023-04-28
# 1  myers.t.6537@ferguson-johnson.net    37609.0  8069089.0  2023-05-19
# 2              swatson8146@payne.net    57113.0  1902144.0  2023-01-29
#
#    order_week  order_year         item_id     category         subcategory  \
# 0        17.0      2023.0  EUD29711-63-6U        decor            wall art
# 1        20.0      2023.0  XDA18116-89-4A  consumables                pens
# 2         4.0      2023.0  ABE59463-05-7E     software  project management
#
#    unit_price  unit_cost  unit_weight    qty  line_number  line_cost
# 0     1096.80     762.71         7.50  105.0          1.0   85597.05
# 1       24.95      15.09         1.49   21.0          0.0     629.79
# 2       13.52       7.86         1.68   39.0          6.0     765.18

# %%
# Create a column for the profit of each line using line cost and line price
df'line_profit'] = (df_rearrange['line_price'].astype('float') - df['line_cost'].astype('float'))
df.head(3)
df['line_price'] = df_rearrange['line_price']
df.head(3)
# Out:
#      first     last              job               phone  \
# 0   Donald  Harding     Immunologist  793-904-7725x39308
# 1  Tiffany    Myers  Music therapist    201.442.4543x942
# 2  Shannon   Watson     Immunologist   687.737.9424x8503
#
#                                email  client_id   order_id  order_date  \
# 0   harding.donald.7185@sullivan.com    58515.0  8953482.0  2023-04-28
# 1  myers.t.6537@ferguson-johnson.net    37609.0  8069089.0  2023-05-19
# 2              swatson8146@payne.net    57113.0  1902144.0  2023-01-29
#
#    order_week  order_year  ...     category         subcategory unit_price  \
# 0        17.0      2023.0  ...        decor            wall art    1096.80
# 1        20.0      2023.0  ...  consumables                pens      24.95
# 2         4.0      2023.0  ...     software  project management      13.52
#
#    unit_cost  unit_weight    qty  line_number  line_cost  line_profit  \
# 0     762.71         7.50  105.0          1.0   85597.05     46241.98
# 1      15.09         1.49   21.0          0.0     629.79       284.48
# 2       7.86         1.68   39.0          6.0     765.18       311.94
#
#    line_price
# 0   131839.03
# 1      914.27
# 2     1077.12
#
# [3 rows x 21 columns]

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above
df['line_price'] = df.loc[:,'order_id'==2742071].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 2
#       1 # Check your work using the totals above
# ----> 2 df['line_price'] = df.loc[:,'order_id'==2742071].sum()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
#    1371 tup = self._validate_tuple_indexer(tup)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1065, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1061 for i, key in enumerate(tup):
#    1062     if is_label_like(key):
#    1063         # We don't need to check for tuples here because those are
#    1064         #  caught by the _is_nested_tuple_indexer check above.
# -> 1065         section = self._getitem_axis(key, axis=i)
#    1067         # We should never have a scalar section here, because
#    1068         #  _getitem_lowerdim is only called after a check for
#    1069         #  is_scalar_access, which that would be.
#    1070         if section.ndim == self.ndim:
#    1071             # we're in the middle of slicing through a MultiIndex
#    1072             # revise the key wrt to `section` by inserting an _NS
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1430, in _LocIndexer._getitem_axis(self, key, axis)
#    1427         return self.obj.iloc[tuple(indexer)]
#    1429 # fall thru to straight lookup
# -> 1430 self._validate_key(key, axis)
#    1431 return self._get_label(key, axis=axis)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1239, in _LocIndexer._validate_key(self, key, axis)
#    1232 ax = self.obj._get_axis(axis)
#    1233 if isinstance(key, bool) and not (
#    1234     is_bool_dtype(ax.dtype)
#    1235     or ax.dtype.name == "boolean"
#    1236     or isinstance(ax, MultiIndex)
#    1237     and is_bool_dtype(ax.get_level_values(0).dtype)
#    1238 ):
# -> 1239     raise KeyError(
#    1240         f"{key}: boolean label can not be used without a boolean index"
#    1241     )
#    1243 if isinstance(key, slice) and (
#    1244     isinstance(key.start, bool) or isinstance(key.stop, bool)
#    1245 ):
#    1246     raise TypeError(f"{key}: boolean values can not be used in a slice")
#
# KeyError: 'False: boolean label can not be used without a boolean index'

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity spend? Check your work from Part 1 for client ids.

# %%
# Create a summary DataFrame showing the totals for the for the top 5 clients with the following information:
# total units purchased, total shipping price, total revenue, and total profit.

# %%
# Format the data and rename the columns to names suitable for presentation.

# Define the money columns. 


# Define a function that converts a dollar amount to millions.


# Apply the currency_format_millions function to only the money columns. 


# Rename the columns to reflect the change in the money format.

# %%
# Sort the updated data by "Total Profit (millions)" form highest to lowest and assign the sort to a new DatFrame.
